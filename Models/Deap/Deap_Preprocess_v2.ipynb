# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import scipy.io as sio
import argparse
import os
import numpy as np
import pandas as pd
import time
import pickle

np.random.seed(0)

def data_1Dto2D(data, Y=9, X=9):
    data_2D = np.zeros([Y, X])
    data_2D[0] = (0,0,0, data[0],0,data[16],0,0,0)
    data_2D[1] = (0,0,0,data[1],0,data[17],0,0,0 )
    data_2D[2] = (data[3],0,data[2],0,data[18],0,data[19],0,data[20])
    data_2D[3] = (0,data[4],0,data[5], 0,data[22],0,data[21],0)
    data_2D[4] = (data[7],0,data[6],0,data[23],0,data[24],0,data[25])
    data_2D[5] = (0,data[8],0,data[9],0,data[27],0, data[26],0)
    data_2D[6] = (data[11], 0,data[10],0, data[15],0,data[28],0,data[29])
    data_2D[7] = (0,0,0,data[12],0,data[30],0, 0, 0)
    data_2D[8] = (0,0,0,data[13],data[14],data[31],0, 0,0)
    # return shape:9*9
    return data_2D

def norm_dataset(dataset_1D):
    print("------------------------------------------------------------------------")
    print("dataset-1D:",dataset_1D.shape)
    norm_dataset_1D = np.zeros([dataset_1D.shape[0], 32])
    for i in range(dataset_1D.shape[0]):
        norm_dataset_1D[i] = feature_normalize(dataset_1D[i])
    # return shape: m*32
    return norm_dataset_1D

def feature_normalize(data):
    mean = data[data.nonzero()].mean()
    sigma = data[data. nonzero ()].std()
    data_normalized = data
    data_normalized[data_normalized.nonzero()] = (data_normalized[data_normalized.nonzero()] - mean)/sigma
    # return shape: 9*9
    return data_normalized

def dataset_1Dto2D(dataset_1D):
    dataset_2D = np.zeros([dataset_1D.shape[0],9,9])
    for i in range(dataset_1D.shape[0]):
        dataset_2D[i] = data_1Dto2D(dataset_1D[i])
    # return shape: m*9*9
    return dataset_2D

def norm_dataset_1Dto2D(dataset_1D):
    norm_dataset_2D = np.zeros([dataset_1D.shape[0], 9, 9])
    for i in range(dataset_1D.shape[0]):
        norm_dataset_2D[i] = feature_normalize( data_1Dto2D(dataset_1D[i]))
    # return shape: m*9*9
    return norm_dataset_2D

def windows(data, size):
    start = 0
    while ((start+size) < data.shape[0]):
        yield int(start), int(start + size)
        start += size

def segment_signal_without_transition(data,label,label_index,window_size):
    print(" label index is:", label_index)  # get data file name and label file name
    print("data shape:", data.shape)
    for (start, end) in windows(data, window_size):
        # print(data.shape)
        if((len(data[start:end]) == window_size)):
            if(start == 0):
                segments = data[start:end]
                segments = np.vstack([segments, data[start:end]])

                labels = np.array(label[label_index])
                labels = np.append(labels, np.array(label[label_index]))
                print("labels:",labels)
            else:
                segments = np.vstack([segments, data[start:end]])
                labels = np.append(labels, np.array(label[label_index])) # labels = np.append(labels, stats.mode(label[start:end])[0][0])
    print(set(labels))
    return segments, labels

def apply_mixup(dataset_file,window_size): # initial empty label arrays
    data_file_in = sio.loadmat(dataset_file)
    data_in = data_file_in["data"].transpose(0,2,1)
    #0 valence, 1 arousal, 2 dominance, 3 liking
    label_in= data_file_in["labels"][:,1]>5
    label_inter = np.empty([0]) # initial empty data arrays
    data_inter_cnn = np.empty([0,window_size, 9, 9])
    data_inter_rnn = np.empty([0, window_size, 32])
    trials = data_in.shape[0]

    # Data pre-processing
    for trial in range(0,trials):
        base_signal = (data_in[trial,0:128,0:32]+data_in[trial,128:256,0:32]+data_in[trial,256:384,0:32])/3
        data = data_in[trial,30:32]84:8064,
        # compute the deviation between baseline signals and experimental signals
        for i in range(0,60):
            data[i*128:(i+1)*128,0:32]=data[i*128:(i+1)*128,0:32]-base_signal
        label_index = trial
        print("trial:",trial)
        #read data and label
        print("data shape: ",data.shape)
        data = norm_dataset(data)
        data, label = segment_signal_without_transition(data, label_in,label_index,window_size)
        # cnn data process
        data_cnn    = dataset_1Dto2D(data)
        data_cnn    = data_cnn.reshape ( int(data_cnn.shape[0]/window_size), window_size, 9, 9)
        # rnn data process
        data_rnn    = data. reshape(int(data.shape[0]/window_size), window_size, 32)
        # append new data and label
        data_inter_cnn  = np.vstack([data_inter_cnn, data_cnn])
        data_inter_rnn  = np.vstack([data_inter_rnn, data_rnn])
        label_inter = np.append(label_inter, label)

    print("total cnn size:", data_inter_cnn.shape)
    print("total rnn size:", data_inter_rnn.shape)
    print("total label size:", label_inter.shape)
    # shuffle data
    index = np.array(range(0, len(label_inter)))
    np.random.shuffle( index)
    shuffled_data_cnn = data_inter_cnn[index]
    shuffled_data_rnn = data_inter_rnn[index]
    shuffled_label = label_inter[index]
    return shuffled_data_cnn ,shuffled_data_rnn,shuffled_label,record

if __name__ == '__main__' :
    begin = time.time()
    print("time begin:",time.localtime())
    dataset_dir = '/content/drive/My Drive/Deap/data/' 
    window_size = 128 
    output_dir  = '/content/drive/My Drive/Deap/deap_shuffled_data/'
    # get directory name for one subject
    for j in range(1,2):
        record_list = [task for task in os.listdir(dataset_dir) if os.path.isfile(os.path.join(dataset_dir,task))]
        print(record_list)
        for record in record_list:
            file = os.path.join(dataset_dir,record)
            #print_top(file, window_size, output_dir)
            print(file,output_dir)
            shuffled_cnn_data,shuffled_rnn_data,shuffled_label,record = apply_mixup(file, window_size)
            output_data_cnn = output_dir+record+"_win_"+str(window_size)+"_cnn_dataset.pkl"
            output_data_rnn = output_dir+record+"_win_"+str(window_size)+"_rnn_dataset.pkl"
            output_label= output_dir+record+"_win_"+str(window_size)+"_labels.pkl"

            with open(output_data_cnn, "wb") as fp:
                pickle.dump( shuffled_cnn_data,fp, protocol=4)
            with open( output_data_rnn, "wb") as fp:
                pickle.dump(shuffled_rnn_data, fp, protocol=4)
            with open(output_label, "wb") as fp:
                pickle.dump(shuffled_label, fp)
            end = time.time()
            print("end time:",time.localtime())
            print("time consuming:",(end-begin))
# Out:
# Streaming output truncated to the last 5000 lines.
# trial: 27
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 27
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 28
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 28
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 29
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 29
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 30
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 30
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 31
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 31
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 32
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 32
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 33
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 33
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 34
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 34
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 35
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 35
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 36
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 36
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 37
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 37
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 38
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 38
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 39
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 39
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# total cnn size: (2400, 128, 9, 9)
# total rnn size: (2400, 128, 32)
# total label size: (2400,)
# end time: time.struct_time(tm_year=2020, tm_mon=5, tm_mday=31, tm_hour=23, tm_min=56, tm_sec=25, tm_wday=6, tm_yday=152, tm_isdst=0)
# time consuming: 541.4773678779602
# /content/drive/My Drive/Deap/data/s18.mat /content/drive/My Drive/Deap/deap_shuffled_data_AROUSAL/
# trial: 0
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 0
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 1
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 1
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 2
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 2
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 3
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 3
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 4
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 4
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 5
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 5
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 6
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 6
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 7
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 7
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 8
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 8
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 9
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 9
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 10
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 10
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 11
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 11
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 12
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 12
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 13
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 13
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 14
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 14
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 15
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 15
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 16
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 16
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 17
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 17
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 18
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 18
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 19
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 19
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 20
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 20
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 21
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 21
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 22
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 22
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 23
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 23
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 24
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 24
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 25
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 25
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 26
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 26
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 27
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 27
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 28
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 28
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 29
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 29
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 30
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 30
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 31
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 31
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 32
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 32
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 33
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 33
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 34
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 34
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 35
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 35
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 36
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 36
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 37
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 37
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 38
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 38
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 39
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 39
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# total cnn size: (2400, 128, 9, 9)
# total rnn size: (2400, 128, 32)
# total label size: (2400,)
# end time: time.struct_time(tm_year=2020, tm_mon=5, tm_mday=31, tm_hour=23, tm_min=56, tm_sec=59, tm_wday=6, tm_yday=152, tm_isdst=0)
# time consuming: 574.9829847812653
# /content/drive/My Drive/Deap/data/s19.mat /content/drive/My Drive/Deap/deap_shuffled_data_AROUSAL/
# trial: 0
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 0
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 1
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 1
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 2
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 2
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 3
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 3
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 4
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 4
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 5
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 5
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 6
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 6
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 7
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 7
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 8
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 8
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 9
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 9
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 10
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 10
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 11
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 11
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 12
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 12
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 13
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 13
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 14
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 14
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 15
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 15
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 16
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 16
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 17
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 17
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 18
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 18
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 19
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 19
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 20
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 20
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 21
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 21
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 22
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 22
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 23
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 23
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 24
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 24
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 25
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 25
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 26
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 26
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 27
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 27
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 28
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 28
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 29
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 29
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 30
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 30
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 31
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 31
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 32
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 32
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 33
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 33
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 34
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 34
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 35
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 35
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 36
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 36
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 37
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 37
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 38
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 38
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 39
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 39
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# total cnn size: (2400, 128, 9, 9)
# total rnn size: (2400, 128, 32)
# total label size: (2400,)
# end time: time.struct_time(tm_year=2020, tm_mon=5, tm_mday=31, tm_hour=23, tm_min=57, tm_sec=31, tm_wday=6, tm_yday=152, tm_isdst=0)
# time consuming: 606.7511193752289
# /content/drive/My Drive/Deap/data/s20.mat /content/drive/My Drive/Deap/deap_shuffled_data_AROUSAL/
# trial: 0
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 0
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 1
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 1
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 2
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 2
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 3
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 3
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 4
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 4
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 5
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 5
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 6
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 6
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 7
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 7
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 8
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 8
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 9
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 9
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 10
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 10
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 11
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 11
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 12
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 12
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 13
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 13
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 14
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 14
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 15
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 15
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 16
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 16
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 17
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 17
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 18
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 18
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 19
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 19
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 20
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 20
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 21
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 21
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 22
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 22
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 23
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 23
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 24
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 24
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 25
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 25
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 26
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 26
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 27
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 27
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 28
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 28
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 29
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 29
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 30
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 30
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 31
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 31
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 32
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 32
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 33
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 33
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 34
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 34
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 35
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 35
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 36
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 36
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 37
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 37
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 38
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 38
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 39
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 39
# data shape: (7680, 32)
# labels: [False False]
# {False}
# total cnn size: (2400, 128, 9, 9)
# total rnn size: (2400, 128, 32)
# total label size: (2400,)
# end time: time.struct_time(tm_year=2020, tm_mon=5, tm_mday=31, tm_hour=23, tm_min=58, tm_sec=1, tm_wday=6, tm_yday=152, tm_isdst=0)
# time consuming: 636.7762007713318
# /content/drive/My Drive/Deap/data/s21.mat /content/drive/My Drive/Deap/deap_shuffled_data_AROUSAL/
# trial: 0
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 0
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 1
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 1
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 2
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 2
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 3
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 3
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 4
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 4
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 5
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 5
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 6
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 6
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 7
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 7
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 8
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 8
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 9
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 9
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 10
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 10
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 11
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 11
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 12
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 12
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 13
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 13
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 14
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 14
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 15
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 15
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 16
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 16
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 17
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 17
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 18
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 18
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 19
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 19
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 20
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 20
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 21
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 21
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 22
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 22
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 23
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 23
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 24
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 24
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 25
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 25
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 26
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 26
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 27
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 27
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 28
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 28
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 29
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 29
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 30
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 30
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 31
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 31
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 32
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 32
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 33
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 33
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 34
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 34
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 35
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 35
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 36
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 36
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 37
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 37
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 38
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 38
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 39
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 39
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# total cnn size: (2400, 128, 9, 9)
# total rnn size: (2400, 128, 32)
# total label size: (2400,)
# end time: time.struct_time(tm_year=2020, tm_mon=5, tm_mday=31, tm_hour=23, tm_min=58, tm_sec=31, tm_wday=6, tm_yday=152, tm_isdst=0)
# time consuming: 667.2868390083313
# /content/drive/My Drive/Deap/data/s22.mat /content/drive/My Drive/Deap/deap_shuffled_data_AROUSAL/
# trial: 0
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 0
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 1
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 1
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 2
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 2
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 3
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 3
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 4
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 4
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 5
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 5
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 6
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 6
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 7
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 7
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 8
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 8
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 9
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 9
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 10
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 10
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 11
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 11
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 12
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 12
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 13
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 13
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 14
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 14
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 15
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 15
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 16
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 16
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 17
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 17
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 18
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 18
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 19
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 19
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 20
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 20
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 21
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 21
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 22
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 22
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 23
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 23
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 24
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 24
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 25
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 25
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 26
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 26
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 27
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 27
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 28
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 28
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 29
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 29
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 30
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 30
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 31
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 31
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 32
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 32
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 33
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 33
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 34
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 34
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 35
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 35
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 36
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 36
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 37
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 37
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 38
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 38
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 39
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 39
# data shape: (7680, 32)
# labels: [False False]
# {False}
# total cnn size: (2400, 128, 9, 9)
# total rnn size: (2400, 128, 32)
# total label size: (2400,)
# end time: time.struct_time(tm_year=2020, tm_mon=5, tm_mday=31, tm_hour=23, tm_min=59, tm_sec=0, tm_wday=6, tm_yday=152, tm_isdst=0)
# time consuming: 696.3942732810974
# /content/drive/My Drive/Deap/data/s23.mat /content/drive/My Drive/Deap/deap_shuffled_data_AROUSAL/
# trial: 0
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 0
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 1
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 1
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 2
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 2
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 3
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 3
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 4
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 4
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 5
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 5
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 6
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 6
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 7
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 7
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 8
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 8
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 9
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 9
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 10
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 10
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 11
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 11
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 12
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 12
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 13
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 13
# data shape: (7680, 32)
# labels: [ True  True]
# ...
# labels: [False False]
# {False}
# trial: 4
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 4
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 5
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 5
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 6
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 6
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 7
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 7
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 8
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 8
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 9
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 9
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 10
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 10
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 11
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 11
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 12
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 12
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 13
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 13
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 14
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 14
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 15
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 15
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 16
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 16
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 17
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 17
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 18
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 18
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 19
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 19
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 20
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 20
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 21
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 21
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 22
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 22
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 23
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 23
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 24
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 24
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 25
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 25
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 26
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 26
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 27
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 27
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 28
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 28
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 29
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 29
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 30
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 30
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 31
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 31
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 32
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 32
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 33
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 33
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 34
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 34
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 35
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 35
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 36
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 36
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 37
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 37
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 38
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 38
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 39
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 39
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# total cnn size: (2400, 128, 9, 9)
# total rnn size: (2400, 128, 32)
# total label size: (2400,)
# end time: time.struct_time(tm_year=2020, tm_mon=6, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=35, tm_wday=0, tm_yday=153, tm_isdst=0)
# time consuming: 971.4177074432373
# /content/drive/My Drive/Deap/data/s32.mat /content/drive/My Drive/Deap/deap_shuffled_data_AROUSAL/
# trial: 0
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 0
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 1
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 1
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 2
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 2
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 3
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 3
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 4
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 4
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 5
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 5
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 6
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 6
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 7
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 7
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 8
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 8
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 9
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 9
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 10
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 10
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 11
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 11
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 12
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 12
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 13
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 13
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 14
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 14
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 15
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 15
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 16
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 16
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 17
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 17
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 18
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 18
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 19
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 19
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 20
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 20
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 21
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 21
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 22
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 22
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 23
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 23
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 24
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 24
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 25
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 25
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 26
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 26
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 27
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 27
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 28
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 28
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 29
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 29
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 30
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 30
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 31
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 31
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 32
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 32
# data shape: (7680, 32)
# labels: [False False]
# {False}
# trial: 33
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 33
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 34
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 34
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 35
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 35
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 36
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 36
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 37
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 37
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 38
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 38
# data shape: (7680, 32)
# labels: [ True  True]
# {True}
# trial: 39
# data shape:  (7680, 32)
# ------------------------------------------------------------------------
# dataset-1D: (7680, 32)
#  label index is: 39
# data shape: (7680, 32)
# labels: [False False]
# {False}
# total cnn size: (2400, 128, 9, 9)
# total rnn size: (2400, 128, 32)
# total label size: (2400,)
# end time: time.struct_time(tm_year=2020, tm_mon=6, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=8, tm_wday=0, tm_yday=153, tm_isdst=0)
# time consuming: 1004.433042049408
