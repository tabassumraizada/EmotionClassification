# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt
#import ffmpeg

# %%
import os
os. chdir("C:/DeapVideoData/face_video/s01")

# %%
os. getcwd()
# Out:
# 'C:\\DeapVideoData\\face_video\\s01'

# %%
cap= cv2.VideoCapture("C:\\DeapVideoData\\face_video\\s01\\s01_trial01.avi")

# %%
type(s01_video)
# Out:
# cv2.VideoCapture

# %%
cap = cv2.VideoCapture(r"C:\\DeapVideoData\\face_video\\s01\\s01_trial01.avi")
counter = 0
while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Display the resulting frame
    if (ret != True):
        break
    cv2.imshow('Video', frame)
    
    print("Frame number: " + str(counter))
    counter = counter+1
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# Frame number: 0
# Frame number: 1
# Frame number: 2
# Frame number: 3
# Frame number: 4
# Frame number: 5
# Frame number: 6
# Frame number: 7
# Frame number: 8
# Frame number: 9
# Frame number: 10
# Frame number: 11
# Frame number: 12
# Frame number: 13
# Frame number: 14
# Frame number: 15
# Frame number: 16
# Frame number: 17
# Frame number: 18
# Frame number: 19
# Frame number: 20
# Frame number: 21
# Frame number: 22
# Frame number: 23
# Frame number: 24
# Frame number: 25
# Frame number: 26
# Frame number: 27
# Frame number: 28
# Frame number: 29
# Frame number: 30
# Frame number: 31
# Frame number: 32
# Frame number: 33
# Frame number: 34
# Frame number: 35
# Frame number: 36
# Frame number: 37
# Frame number: 38
# Frame number: 39
# Frame number: 40
# Frame number: 41
# Frame number: 42
# Frame number: 43
# Frame number: 44
# Frame number: 45
# Frame number: 46
# Frame number: 47
# Frame number: 48
# Frame number: 49
# Frame number: 50
# Frame number: 51
# Frame number: 52
# ...

# %%
from scipy.io import loadmat

# %%
df=loadmat('C://Users//tabas//Documents//JupyterNotebook_Python//Deap//matlab//s01.mat')

# %%
df.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'labels', 'data'])

# %%
# 40 channels
# 40 trials per person
# 8064 readings @ 128 hz. That is equivalent to 128 readings per sec for 63 sec
df['data'].shape
# Out:
# (40, 40, 8064)

# %%
df['data'][0][0]
# Out:
# array([ 0.94823168,  1.65333533,  3.01372577, ..., -2.82648937,
#        -4.47722969, -3.67692812])

# %%
df['data'][0][31]
# Out:
# array([0.37227063, 2.07619495, 4.46521875, ..., 2.23958511, 3.18256605,
#        4.70807159])

# %%
df['labels'].shape
# Out:
# (40, 4)

# %%
type(df['labels'])
# Out:
# numpy.ndarray

# %%
# Range of values (maximum - minimum) along an axis.
np.ptp(df['labels'],axis=0)
# Out:
# array([7.64, 6.07, 6.96, 4.6 ])

# %%
np.nanmax(df['labels'],axis=0)
# Out:
# array([9.  , 8.15, 9.  , 8.47])

# %%
np.nanmin(df['labels'],axis=0)
# Out:
# array([1.36, 2.08, 2.04, 3.87])

# %%
df['labels'][:,3]
# Out:
# array([7.83, 8.47, 7.08, 8.06, 6.05, 8.03, 7.04, 5.87, 5.99, 7.09, 6.24,
#        7.35, 6.18, 5.04, 5.04, 7.14, 6.41, 8.01, 6.79, 8.13, 7.86, 7.37,
#        7.9 , 8.22, 7.21, 8.24, 7.29, 7.87, 8.14, 7.33, 8.04, 3.95, 5.13,
#        6.92, 5.18, 3.87, 6.77, 6.62, 6.15, 5.97])
