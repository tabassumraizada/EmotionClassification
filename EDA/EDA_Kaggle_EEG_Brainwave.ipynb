# %% [markdown]
# # EDA for Kaggle Dataset

# %%
# Import required Libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
# Load dataset
brainwave_df = pd.read_csv('eeg-brainwave-dataset-feeling-emotions//emotions.csv')

# %%
# Sample the dataset
brainwave_df.head()
# Out:
#    # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  mean_d_1_a  \
# 0        4.62      30.3    -356.0      15.6      26.3       1.070       0.411
# 1       28.80      33.1      32.0      25.8      22.8       6.550       1.680
# 2        8.90      29.4    -416.0      16.7      23.7      79.900       3.360
# 3       14.90      31.6    -143.0      19.8      24.3      -0.584      -0.284
# 4       28.30      31.3      45.2      27.3      24.5      34.800      -5.790
#
#    mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  fft_742_b  fft_743_b  \
# 0      -15.70        2.06        3.15  ...       23.5       20.3       20.3
# 1        2.88        3.83       -4.82  ...      -23.3      -21.8      -21.8
# 2       90.20       89.90        2.03  ...      462.0     -233.0     -233.0
# 3        8.82        2.30       -1.97  ...      299.0     -243.0     -243.0
# 4        3.06       41.40        5.52  ...       12.0       38.1       38.1
#
# ...

# %%
brainwave_df.tail()
# Out:
#       # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  \
# 2127      32.400      32.2      32.2     30.80      23.4        1.64
# 2128      16.300      31.3    -284.0     14.30      23.9        4.20
# 2129      -0.547      28.3    -259.0     15.80      26.7        9.08
# 2130      16.800      19.9    -288.0      8.34      26.0        2.46
# 2131      27.000      32.0      31.8     25.00      28.9        4.99
#
#       mean_d_1_a  mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  \
# 2127       -2.03       0.647      -0.121       -1.10  ...     -21.70
# 2128        1.09       4.460       4.720        6.63  ...     594.00
# 2129        6.90      12.700       2.030        4.64  ...     370.00
# 2130        1.58     -16.000       1.690        4.74  ...     124.00
# 2131        1.95       6.210       3.490       -3.51  ...       1.95
#
#       fft_742_b  fft_743_b  fft_744_b  fft_745_b  fft_746_b  fft_747_b  \
# ...

# %% [markdown]
# #### From the results above we see that the dataset has 2549 columns and the last one is the label. These are classified into 3 types Neutral, Positive and Negative

# %%
# Look at the shape of the dataset. Refer to experimental setup of Kaggle dataset for this reduced dimensionality
brainwave_df.shape
# Out:
# (2132, 2549)

# %% [markdown]
# In this dataset feature  selection  algorithms  were  run  to  generate  a  reduced dataset from  the  2,549  source attributes.

# %%
# Check the datatype (all float64
brainwave_df.dtypes
# Out:
# # mean_0_a    float64
# mean_1_a      float64
# mean_2_a      float64
# mean_3_a      float64
# mean_4_a      float64
#                ...
# fft_746_b     float64
# fft_747_b     float64
# fft_748_b     float64
# fft_749_b     float64
# label          object
# Length: 2549, dtype: object

# %%
brainwave_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2132 entries, 0 to 2131
# Columns: 2549 entries, # mean_0_a to label
# dtypes: float64(2548), object(1)
# memory usage: 41.5+ MB

# %%
# Look at the distribution of values for each column
brainwave_df.describe()
# Out:
#         # mean_0_a     mean_1_a     mean_2_a     mean_3_a     mean_4_a  \
# count  2132.000000  2132.000000  2132.000000  2132.000000  2132.000000
# mean     15.256914    27.012462  -104.975629    13.605898    24.150483
# std      15.284621     9.265141   206.271960    16.874676    14.187340
# min     -61.300000  -114.000000  -970.000000  -137.000000  -217.000000
# 25%       6.577500    26.075000  -195.000000     4.857500    23.600000
# 50%      14.100000    30.000000    14.950000    15.400000    25.200000
# 75%      27.700000    31.400000    29.600000    26.500000    26.800000
# max     304.000000    42.300000   661.000000   206.000000   213.000000
#
#         mean_d_0_a   mean_d_1_a   mean_d_2_a   mean_d_3_a   mean_d_4_a  ...  \
# count  2132.000000  2132.000000  2132.000000  2132.000000  2132.000000  ...
# mean      0.025378     0.052282     0.301655     0.036793     0.083567  ...
# std      17.981796     8.509174    68.098894    17.010031    18.935378  ...
# ...

# %%
# We will check to see the distribution of this data across the 3 emotional states that we plan to evaluate by using a countplot

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.figure(figsize=(12,5))
sns.countplot(x=brainwave_df.label, color='lightgreen')
plt.title('Emotional sentiment class distribution', fontsize=14)
plt.ylabel('Class Counts', fontsize=12)
plt.xlabel('Class Label', fontsize=12)
plt.xticks(rotation='45')
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %% [markdown]
# The dataset has fairly even distribution of data across for the 3 emotions

# %%
# We Will use pandas’ function value_counts to see the exact number across the 3 types
brainwave_df['label'].value_counts()
# Out:
# NEUTRAL     716
# POSITIVE    708
# NEGATIVE    708
# Name: label, dtype: int64

# %%
#Check the data for nulls
np.count_nonzero(brainwave_df.isnull())
# Out:
# 0

# %% [markdown]
# No nulls were found in the prepared dataset
